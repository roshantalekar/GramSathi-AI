# %% [markdown]
# # GramSathi AI
#
# ## AI-Powered Rural Infrastructure Planning & Citizen Monitoring Platform
#
# ### Developed By:
# (ROSHAN DNYANESHWAR TALEKAR)

# %%
# ===========================
# GramSathi AI
# Project Setup
# ===========================

import warnings
warnings.filterwarnings("ignore")

import os
import sys

import numpy as np
import pandas as pd

print("Project Libraries Loaded Successfully ✅")
# Out:
# Project Libraries Loaded Successfully ✅

# %%
folders = [
    "../datasets/raw",
    "../datasets/processed",
    "../outputs",
    "../models",
    "../reports",
    "../images"
]

for folder in folders:
    os.makedirs(folder, exist_ok=True)

print("Project Folder Structure Created Successfully ✅")
# Out:
# Project Folder Structure Created Successfully ✅

# %%
project_path = ".."

for root, dirs, files in os.walk(project_path):
    level = root.replace(project_path, "").count(os.sep)
    indent = " " * 4 * level
    print(f"{indent}{os.path.basename(root)}/")
# Out:
# ../
#     .ipynb_checkpoints/
#     burger website/
#     College Details/
#     Data analytics project/
#         .ipynb_checkpoints/
#     datasets/
#         processed/
#         raw/
#     excel assignment/
#     excel btm class/
#     gram sathi ai/
#         .ipynb_checkpoints/
#     images/
#     loginwr project/
#         analytics_reports/
#         assets/
#         databases/
#         models/
#         modules/
#             __pycache__/
#         music/
#             mood/
#             party/
#             relaxing/
#             study/
#             workout/
#         PROJECT/
#             streamlit_splm/
#                 __pycache__/
#             workout_reports/
#         streamlit_splm/
#             __pycache__/
#         workout_reports/
#     models/
#     New folder/
#         COLLEGE FSD/
#             LAB 1b/
#                 env/
#                     Include/
#                     Lib/
#                         site-packages/
# ...

# %%
project = {
    "Project Name": "GramSathi AI",
    "Version": "1.0",
    "Author": "Your Name",
    "Project Type": "End-to-End AI + ML + GIS",
    "Status": "Development"
}

pd.DataFrame(project.items(), columns=["Field", "Value"])

# %%
print("""
Why GramSathi AI?

Many rural areas still lack:

✔ Proper Roads
✔ Street Lights
✔ Drainage
✔ Safe Connectivity

Current surveys are manual and time-consuming.

GramSathi AI aims to assist planning using
Artificial Intelligence and Geospatial Analysis.
""")
